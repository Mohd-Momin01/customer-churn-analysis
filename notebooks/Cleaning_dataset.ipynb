# %%
# Import libraries

import pandas as pd
import numpy as np

# Load dataset

df = pd.read_csv("../Raw_Data/customer_churn_data.csv")

print("Dataset loaded successfully!")
print(df.shape)

df.head()
# Out:
# Dataset loaded successfully!
# (10000, 35)
#   Customer_ID     Customer_Name  Gender  Age Senior_Citizen Dependents  \
# 0     C000001     Aryan Maharaj    Male   49             No        Yes
# 1     C000002       Udant Dewan  Female   53             No         No
# 2     C000003        Gagan Sami  Female   67            Yes        Yes
# 3     C000004  Ayushman Chander  Female   54             No        Yes
# 4     C000005      Viraj Tiwari    Male   65            Yes        Yes
#
#          State       City  PIN_Code Customer_Segment  ...  Support_Tickets  \
# 0      Gujarat   Vadodara    301494            Value  ...                3
# 1    Karnataka  Bengaluru    298908       High Value  ...                3
# 2    Telangana  Hyderabad    966452            Value  ...                1
# 3        Delhi      Delhi    191990          Premium  ...                1
# 4  West Bengal    Kolkata    133568          Premium  ...                3
#
# ...

# %%
import os

print("Current folder:")
print(os.getcwd())

print("\nFiles in current folder:")
print(os.listdir())
# Out:
# Current folder:
# c:\DATA ANAYLTCS\SQL PROJECT + POWER BI\SQL+PYTHON+EXCEL+POWER BI\churn Sales Analysis\Dataset\Cleaned_Data
#
# Files in current folder:
# ['Cleaning_dataset.ipynb']
